# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
# %matplotlib inline

# %%
plt.rcParams['font.family']='Malgun Gothic'
plt.rcParams['axes.unicode_minus'] = False

# %%
book=pd.read_csv('Book_cleansing_data_file.csv',index_col=0)
book
# Out:
#                  title publishDate  author_id author_name  publisher_id  \
# isbn
# 6.000028e+09    스콜피언 1  2000-01-30       10.0         최진수         159.0
# 6.000030e+09  으뜸글 평양아리  2001-06-09        4.0       으뜸 열롤         160.0
# 6.000041e+09     인간의 벽  1984-12-05       12.0         문순태           5.0
# 6.000041e+09      황금깃털  1984-08-15       13.0         서영은           5.0
# 6.000046e+09  태양과 그늘 1  2001-12-11       17.0         정광섭         161.0
# ...                ...         ...        ...         ...           ...
# NaN                NaN         NaN        NaN         NaN           NaN
# NaN                NaN         NaN        NaN         NaN           NaN
# NaN                NaN         NaN        NaN         NaN           NaN
# NaN                NaN         NaN        NaN         NaN           NaN
# NaN                NaN         NaN        NaN         NaN           NaN
#
#              publisher_name   price  pageCount     size  weight  rating  \
# isbn
# ...

# %%
best_author=pd.read_csv('Best_cleansing_data_file.csv')
best_author
# Out:
#              isbn                     title publishDate  author_id  \
# 0    8.936434e+09  소년이 온다 (10주년 한정 특별판, 양장)  2014-05-19        193
# 1    9.788900e+12                    기억의 낙원  2024-08-22       2501
# 2    9.788930e+12                  젊은 날의 초상  2020-06-17        131
# 3    9.788930e+12                     도깨비 1  2017-01-31        163
# 4    9.788930e+12                     도깨비 2  2017-02-20        163
# ..            ...                       ...         ...        ...
# 995  9.791200e+12                   센트 아일랜드  2024-07-25       2396
# 996  9.791200e+12                    그들의 하루  2024-11-20        999
# 997  9.791200e+12                      킬에이저  2024-08-08       2497
# 998  9.791200e+12                 비나이다 비나이다  2024-08-27       2526
# 999  9.791200e+12                    폴리스 마마  2024-12-01       2595
#
#     author_name  publisher_id publisher_name  price  pageCount     size  \
# 0            한강             1             창비  15000        284  22936.0
# ...

# %%
book_author=pd.read_csv('Book_cleansing_data_file.csv')
book_author
# Out:
#               isbn     title publishDate  author_id author_name  publisher_id  \
# 0     6.000028e+09    스콜피언 1  2000-01-30       10.0         최진수         159.0
# 1     6.000030e+09  으뜸글 평양아리  2001-06-09        4.0       으뜸 열롤         160.0
# 2     6.000041e+09     인간의 벽  1984-12-05       12.0         문순태           5.0
# 3     6.000041e+09      황금깃털  1984-08-15       13.0         서영은           5.0
# 4     6.000046e+09  태양과 그늘 1  2001-12-11       17.0         정광섭         161.0
# ...            ...       ...         ...        ...         ...           ...
# 2983           NaN       NaN         NaN        NaN         NaN           NaN
# 2984           NaN       NaN         NaN        NaN         NaN           NaN
# 2985           NaN       NaN         NaN        NaN         NaN           NaN
# 2986           NaN       NaN         NaN        NaN         NaN           NaN
# 2987           NaN       NaN         NaN        NaN         NaN           NaN
#
# ...

# %%
best=pd.read_csv('Best_cleansing_data_file.csv',index_col=0)
best
# Out:
#                                  title publishDate  author_id author_name  \
# isbn
# 8.936434e+09  소년이 온다 (10주년 한정 특별판, 양장)  2014-05-19        193          한강
# 9.788900e+12                    기억의 낙원  2024-08-22       2501         김상균
# 9.788930e+12                  젊은 날의 초상  2020-06-17        131         이문열
# 9.788930e+12                     도깨비 1  2017-01-31        163         김수연
# 9.788930e+12                     도깨비 2  2017-02-20        163         김수연
# ...                                ...         ...        ...         ...
# 9.791200e+12                   센트 아일랜드  2024-07-25       2396         김유진
# 9.791200e+12                    그들의 하루  2024-11-20        999         차인표
# 9.791200e+12                      킬에이저  2024-08-08       2497         신아인
# 9.791200e+12                 비나이다 비나이다  2024-08-27       2526         신도윤
# 9.791200e+12                    폴리스 마마  2024-12-01       2595         한지승
#
# ...

# %%
best.head()
# Out:
#                                  title publishDate  author_id author_name  \
# isbn
# 8.936434e+09  소년이 온다 (10주년 한정 특별판, 양장)  2014-05-19        193          한강
# 9.788900e+12                    기억의 낙원  2024-08-22       2501         김상균
# 9.788930e+12                  젊은 날의 초상  2020-06-17        131         이문열
# 9.788930e+12                     도깨비 1  2017-01-31        163         김수연
# 9.788930e+12                     도깨비 2  2017-02-20        163         김수연
#
#               publisher_id publisher_name  price  pageCount     size  weight  \
# isbn
# 8.936434e+09             1             창비  15000        284  22936.0     398
# 9.788900e+12             2        웅진지식하우스  17000        316  26800.0     411
# 9.788930e+12             3   알에이치코리아(RHK)  15000        304  29400.0     396
# 9.788930e+12             3   알에이치코리아(RHK)  16800        300  23876.0     364
# 9.788930e+12             3   알에이치코리아(RHK)  16800        300  24064.0     436
#
# ...

# %% [markdown]
# # 결측치
# - 개수

# %%
best.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1000 entries, 8936434128.0 to 9791200000000.0
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   title             1000 non-null   object
#  1   publishDate       1000 non-null   object
#  2   author_id         1000 non-null   int64
#  3   author_name       1000 non-null   object
#  4   publisher_id      1000 non-null   int64
#  5   publisher_name    1000 non-null   object
#  6   price             1000 non-null   int64
#  7   pageCount         1000 non-null   int64
#  8   size              999 non-null    float64
#  9   weight            1000 non-null   int64
#  10  rating            1000 non-null   float64
#  11  shortReviewCount  909 non-null    float64
#  12  fullReviewCount   943 non-null    float64
#  13  records           155 non-null    object
# dtypes: float64(4), int64(5), object(5)
# memory usage: 117.2+ KB

# %%
best['records'].unique()
# Out:
# array([nan, '한국소설 주간 41위, 종합 top100 3주', '소설/시/희곡 주간 35위, 종합 top10 3주',
#        '한국소설 주간 37위, 종합 top100 5주', '달력/기타 주간 1위, 종합 top100 5주',
#        '판타지/환상문학 주간 26위, 소설/시/희곡 top100 8주',
#        '한국 과학소설 주간 37위, 소설/시/희곡 top100 5주', '한국 과학소설 주간 49위',
#        '한국 과학소설 주간 45위', '판타지/환상문학 주간 16위, 소설/시/희곡 top100 5주',
#        '한국판타지/환상소설 주간 33위, 소설/시/희곡 top100 3주',
#        '판타지/환상문학 주간 50위, 소설/시/희곡 top100 3주',
#        '판타지/환상문학 주간 36위, 소설/시/희곡 top100 3주',
#        '판타지/환상문학 주간 15위, 소설/시/희곡 top100 3주',
#        '한국판타지/환상소설 주간 43위, 소설/시/희곡 top100 3주',
#        '판타지/환상문학 주간 14위, 소설/시/희곡 top100 4주',
#        '판타지/환상문학 주간 49위, 소설/시/희곡 top100 4주',
#        '판타지/환상문학 주간 48위, 소설/시/희곡 top100 3주',
#        '판타지/환상문학 주간 25위, 소설/시/희곡 top100 4주',
#        '판타지/환상문학 주간 35위, 소설/시/희곡 top100 2주',
#        '판타지/환상문학 주간 24위, 소설/시/희곡 top100 2주',
#        '판타지/환상문학 주간 47위, 소설/시/희곡 top100 2주',
#        '판타지/환상문학 주간 33위, 소설/시/희곡 top100 5주',
#        '판타지/환상문학 주간 46위, 소설/시/희곡 top100 5주',
# ...

# %%
book.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2988 entries, 6000027854.0 to nan
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   title             2315 non-null   object
#  1   publishDate       2315 non-null   object
#  2   author_id         2315 non-null   float64
#  3   author_name       2315 non-null   object
#  4   publisher_id      2315 non-null   float64
#  5   publisher_name    2315 non-null   object
#  6   price             2315 non-null   float64
#  7   pageCount         2315 non-null   float64
#  8   size              2296 non-null   float64
#  9   weight            2315 non-null   float64
#  10  rating            2315 non-null   float64
#  11  shortReviewCount  531 non-null    float64
#  12  fullReviewCount   740 non-null    float64
#  13  records           2 non-null      object
#  14  bookDescription   1604 non-null   object
#  15  bookExcerpt       628 non-null    object
# ...

# %%
book['records'].unique()
# Out:
# array([nan, '멜로·로맨스 주간 1위, 소설/시/희곡 top100 5주', '대체역사/가상소설 주간 6위'],
#       dtype=object)

# %% [markdown]
# # 이상치, 분포
# - area,price,pagecount, weight, rating, shortreviewcount, fullreviewcount,

# %% [markdown]
# ## 베스트셀러

# %%
best['shortReviewCount'].describe()
# Out:
# count    909.000000
# mean      27.529153
# std       66.415646
# min        1.000000
# 25%        4.000000
# 50%        9.000000
# 75%       22.000000
# max      809.000000
# Name: shortReviewCount, dtype: float64

# %%
counts, bins, patches= plt.hist(best['size'], bins=20, edgecolor='black')
plt.title("책 크기 분포")
plt.xlabel("크기 (cm^2)")
plt.ylabel("빈도")
for count, patch in zip(counts, patches):
    if count>0:
        plt.text(patch.get_x() + patch.get_width()/2, count, int(count),
                 ha='center', va='bottom', fontsize=8)
plt.show()

# %%
plt.boxplot(best['price'])
plt.title("가격")
plt.ylabel('원')
plt.show()

# %%
counts, bins, patches= plt.hist(best['price'], bins=30, edgecolor='black')
plt.title("가격")
plt.xlabel("원")
plt.ylabel("빈도")
plt.xticks(np.arange(0, 170000, 5000))#5000원 단위로
plt.xticks(rotation=45)
for count, patch in zip(counts, patches):
    if count>0:
        plt.text(patch.get_x() + patch.get_width()/2, count, int(count),
                 ha='center', va='bottom', fontsize=8)
plt.show()

# %%
plt.boxplot(best['pageCount'])
plt.title("페이지수")
plt.ylabel('쪽')
plt.show()

# %%
counts, bins, patches= plt.hist(best['pageCount'], bins=30, edgecolor='black')
plt.title("페이지수")
plt.xlabel("쪽")
plt.ylabel("빈도")
plt.xticks(np.arange(0, 4800, 200))#5000원 단위로
plt.xticks(rotation=45)
for count, patch in zip(counts, patches):
    if count>0:
        plt.text(patch.get_x() + patch.get_width()/2, count, int(count),
                 ha='center', va='bottom', fontsize=8)
plt.show()

# %%
plt.boxplot(best['weight'])
plt.title("무게")
plt.ylabel('g')
plt.show()

# %%
counts, bins, patches= plt.hist(best['weight'], bins=30, edgecolor='black')
plt.title("무게")
plt.xlabel("g")
plt.ylabel("빈도")
plt.xticks(np.arange(0, 6720, 250))#5000원 단위로
plt.xticks(rotation=45)
for count, patch in zip(counts, patches):
    if count>0:
        plt.text(patch.get_x() + patch.get_width()/2, count, int(count),
                 ha='center', va='bottom', fontsize=8)
plt.show()

# %%
plt.boxplot(best['rating'])
plt.title("평가")
plt.ylabel('점')
plt.show()

# %%
counts, bins, patches= plt.hist(best['rating'], bins=30, edgecolor='black')
plt.title("평가")
plt.xlabel("점")
plt.ylabel("빈도")
plt.xticks(np.arange(0, 10, 1))#5000원 단위로
plt.xticks(rotation=45)
for count, patch in zip(counts, patches):
    if count>0:
        plt.text(patch.get_x() + patch.get_width()/2, count, int(count),
                 ha='center', va='bottom', fontsize=8)
plt.show()

# %%
counts, bins, patches= plt.hist(best['shortReviewCount'], bins=30, edgecolor='black')
plt.title("100자평")
plt.xlabel("개")
plt.ylabel("빈도")
plt.xticks(np.arange(0, 809, 30))#5000원 단위로
plt.xticks(rotation=45)
for count, patch in zip(counts, patches):
    if count>0:
        plt.text(patch.get_x() + patch.get_width()/2, count, int(count),
                 ha='center', va='bottom', fontsize=8)
plt.show()

# %%
counts, bins, patches= plt.hist(best['fullReviewCount'], bins=30, edgecolor='black')
plt.title("리뷰")
plt.xlabel("개")
plt.ylabel("빈도")
plt.xticks(np.arange(0, 809, 30))#5000원 단위로
plt.xticks(rotation=45)
for count, patch in zip(counts, patches):
    if count>0:
        plt.text(patch.get_x() + patch.get_width()/2, count, int(count),
                 ha='center', va='bottom', fontsize=8)
plt.show()

# %%
publisher=best['publisher_name'].value_counts()
bars = plt.bar(publisher.index,publisher.values)
plt.figure(figsize=(25,15))
publisher.plot(kind='bar')
plt.title('출판사')
plt.ylabel('책출판수')
plt.xlabel('출판사')
plt.xticks(rotation=90)
for bar in bars:
    height = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, height, f'{int(height)}',
             ha='center', va='bottom', fontsize=9)
plt.show()

# %%
best['publish_month'] = pd.to_datetime(best['publishDate'], errors='coerce').dt.to_period('M')

plt.figure(figsize=(20, 10))
monthly_counts = best['publish_month'].astype(str).value_counts().sort_index()
bars = plt.bar(monthly_counts.index,monthly_counts.values)
monthly_counts.plot(kind='bar')
plt.title("월별 출간 도서 수")
plt.ylabel("도서 수")
plt.xlabel("년별 월")
plt.xticks(rotation=90)
for bar in bars:
    height = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, height, f'{int(height)}',
             ha='center', va='bottom', fontsize=9)
plt.show()

# %%
bestauthor = best_author['author_id'].value_counts()
id_to_name = best_author.drop_duplicates(subset='author_id').set_index('author_id')['author_name']#id이름 매핑
bestauthor.index = bestauthor.index.map(id_to_name)
bars = plt.bar(bestauthor.index,bestauthor.values)
plt.figure(figsize=(200,15))
bestauthor.plot(kind='bar')
plt.title('작가')
plt.ylabel('책출판수')
plt.xlabel('작가')
plt.xticks(rotation=90)
for bar in bars:
    height = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, height, f'{int(height)}',
             ha='center', va='bottom', fontsize=9)
plt.show()

# %% [markdown]
# # 일반도서

# %%
book['price'].describe()
# Out:
# count      2315.000000
# mean      13486.177106
# std       16769.982826
# min        1000.000000
# 25%        9150.000000
# 50%       12000.000000
# 75%       14800.000000
# max      650000.000000
# Name: price, dtype: float64

# %%
counts, bins, patches= plt.hist(book['size'], bins=20, edgecolor='black')
plt.title("책 크기 분포")
plt.xlabel("크기 (cm^2)")
plt.ylabel("빈도")
for count, patch in zip(counts, patches):
    if count>0:
        plt.text(patch.get_x() + patch.get_width()/2, count, int(count),
                 ha='center', va='bottom', fontsize=8)
plt.show()

# %%
plt.boxplot(book['price'])
plt.title("가격")
plt.ylabel('원')
plt.show()

# %%
plt.figure(figsize=(20, 10))
counts, bins, patches= plt.hist(book['price'], bins=30, edgecolor='black')
plt.title("가격")
plt.xlabel("원")
plt.ylabel("빈도")
plt.xticks(np.arange(0, 650000, 10000))#5000원 단위로
plt.xticks(rotation=45)
# 막대 위에 "빈도 (가격범위)" 같이 표시
for count, patch, left, right in zip(counts, patches, bins[:-1], bins[1:]):
    if count > 0:
        label = f"{int(count)}\n({int(left/1000)}K~{int(right/1000)}K)"
        plt.text(patch.get_x() + patch.get_width()/2, count,
                 label,
                 ha='center', va='bottom', fontsize=7)
  # 폰트 작게

plt.show()

# %%
plt.boxplot(book['pageCount'])
plt.title("페이지수")
plt.ylabel('쪽')
plt.show()

# %%
counts, bins, patches= plt.hist(book['pageCount'], bins=30, edgecolor='black')
plt.title("페이지수")
plt.xlabel("쪽")
plt.ylabel("빈도")
plt.xticks(np.arange(0, 4800, 200))#5000원 단위로
plt.xticks(rotation=45)
for count, patch in zip(counts, patches):
    if count>0:
        plt.text(patch.get_x() + patch.get_width()/2, count, int(count),
                 ha='center', va='bottom', fontsize=8)
plt.show()

# %%
plt.boxplot(book['weight'])
plt.title("무게")
plt.ylabel('g')
plt.show()

# %%
counts, bins, patches= plt.hist(book['weight'], bins=30, edgecolor='black')
plt.title("무게")
plt.xlabel("g")
plt.ylabel("빈도")
plt.xticks(np.arange(0, 11000, 250))#5000원 단위로
plt.xticks(rotation=45)
for count, patch in zip(counts, patches):
    if count>0:
        plt.text(patch.get_x() + patch.get_width()/2, count, int(count),
                 ha='center', va='bottom', fontsize=8)
plt.show()

# %%
plt.boxplot(book['rating'])
plt.title("평가")
plt.ylabel('점')
plt.show()

# %%
counts, bins, patches= plt.hist(book['rating'], bins=30, edgecolor='black')
plt.title("평가")
plt.xlabel("점")
plt.ylabel("빈도")
plt.xticks(np.arange(0, 10, 1))#5000원 단위로
plt.xticks(rotation=45)
for count, patch in zip(counts, patches):
    if count>0:
        plt.text(patch.get_x() + patch.get_width()/2, count, int(count),
                 ha='center', va='bottom', fontsize=8)
plt.show()

# %%
counts, bins, patches= plt.hist(book['shortReviewCount'], bins=30, edgecolor='black')
plt.title("100자평")
plt.xlabel("개")
plt.ylabel("빈도")
plt.xticks(np.arange(0, 809, 30))#5000원 단위로
plt.xticks(rotation=45)
for count, patch in zip(counts, patches):
    if count>0:
        plt.text(patch.get_x() + patch.get_width()/2, count, int(count),
                 ha='center', va='bottom', fontsize=8)
plt.show()

# %%
counts, bins, patches= plt.hist(book['fullReviewCount'], bins=30, edgecolor='black')
plt.title("리뷰")
plt.xlabel("개")
plt.ylabel("빈도")
plt.xticks(np.arange(0, 809, 30))#5000원 단위로
plt.xticks(rotation=45)
for count, patch in zip(counts, patches):
    if count>0:
        plt.text(patch.get_x() + patch.get_width()/2, count, int(count),
                 ha='center', va='bottom', fontsize=8)
plt.show()

# %%
publisher=book['publisher_name'].value_counts()
bars = plt.bar(publisher.index,publisher.values)
plt.figure(figsize=(180,15))
publisher.plot(kind='bar')
plt.title('출판사')
plt.ylabel('책출판수')
plt.xlabel('출판사')
plt.xticks(rotation=90)
for bar in bars:
    height = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, height, f'{int(height)}',
             ha='center', va='bottom', fontsize=9)
plt.show()

# %%
bookauthor = book_author['author_id'].value_counts()
id_to_name = book_author.drop_duplicates(subset='author_id').set_index('author_id')['author_name']#id이름 매핑
bookauthor.index = bookauthor.index.map(id_to_name)
bars = plt.bar(bookauthor.index,bookauthor.values)
plt.figure(figsize=(280,15))
bookauthor.plot(kind='bar')
plt.title('작가')
plt.ylabel('책출판수')
plt.xlabel('작가')
plt.xticks(rotation=90)
for bar in bars:
    height = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, height, f'{int(height)}',
             ha='center', va='bottom', fontsize=9)
plt.show()

# %%
book['publish_month'] = pd.to_datetime(book['publishDate'], errors='coerce').dt.to_period('M')

plt.figure(figsize=(20, 10))
monthly_counts = best['publish_month'].astype(str).value_counts().sort_index()
bars = plt.bar(monthly_counts.index,monthly_counts.values)
monthly_counts.plot(kind='bar')
plt.title("월별 출간 도서 수")
plt.ylabel("도서 수")
plt.xlabel("년별 월")
plt.xticks(rotation=90)
for bar in bars:
    height = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, height, f'{int(height)}',
             ha='center', va='bottom', fontsize=9)
plt.show()

# %%
best['size'].describe()
# Out:
# count      999.000000
# mean     25726.289289
# std       4262.686174
# min      18000.000000
# 25%      24032.000000
# 50%      24960.000000
# 75%      27336.000000
# max      57750.000000
# Name: size, dtype: float64

# %%
book['size'].describe()
# Out:
# count     2296.000000
# mean     31937.510453
# std       6540.513886
# min      15540.000000
# 25%      29000.000000
# 50%      31080.000000
# 75%      33896.000000
# max      62370.000000
# Name: size, dtype: float64

# %%
best['pageCount'].describe()
# Out:
# count    1000.00000
# mean      317.51100
# std       239.58531
# min        16.00000
# 25%       232.00000
# 50%       296.00000
# 75%       360.00000
# max      4800.00000
# Name: pageCount, dtype: float64

# %%
book['pageCount'].describe()
# Out:
# count    2315.000000
# mean      313.548596
# std       219.434387
# min         1.000000
# 25%       256.000000
# 50%       300.000000
# 75%       350.000000
# max      8256.000000
# Name: pageCount, dtype: float64

# %%
best['rating'].describe()
# Out:
# count    1000.000000
# mean        8.912400
# std         1.636608
# min         0.000000
# 25%         8.700000
# 50%         9.300000
# 75%         9.600000
# max        10.000000
# Name: rating, dtype: float64

# %%
book['rating'].describe()
# Out:
# count    2315.000000
# mean        3.238618
# std         4.275759
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         8.200000
# max        10.000000
# Name: rating, dtype: float64
